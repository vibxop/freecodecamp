# %%
name = input("What is your name? ")
print("Hello, " + name + "!")
# Out:
# Hello, pranav!

# %%
def calculate_sum(a, b):
    print("The sum of", a, "and", b, "is", a + b)
calculate_sum(5, 10)
# Out:
# The sum of 5 and 10 is 15

# %%
def calculate_sum(a, b):
    return a + b
my_sum = calculate_sum(5, 10)
print("sum is:", my_sum)
# Out:
# sum is: 15
