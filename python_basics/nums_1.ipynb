# %%
my_int_1 = 56
my_int_2 = -4
print(type(my_int_1))
print(type(my_int_2))
# Out:
# <class 'int'>
# <class 'int'>

# %%
my_int_1= 56
my_int_2 = 7
sum_of_ints = my_int_1 + my_int_2
print(sum_of_ints)
# Out:
# 63

# %%
my_int_1= 56
my_int_2 = 3
difference_of_ints = my_int_1 - my_int_2
print(difference_of_ints)
# Out:
# 53

# %%
my_int_1= 56
my_int_2 = 2
product_of_ints = my_int_1 * my_int_2
print(product_of_ints)
# Out:
# 112

# %%
my_int_1= 56
my_int_2 = 4
division_of_ints = my_int_1 / my_int_2
print(division_of_ints)
# Out:
# 14.0

# %%
my_float_1 = 3.14
my_float_2 = -3.14
print(type(my_float_1)) 
print(type(my_float_2))
# Out:
# <class 'float'>
# <class 'float'>

# %%
my_float_1 = 3.14
my_float_2 = 1.21
sum_of_floats = my_float_1 + my_float_2
subtraction_of_floats = my_float_1 - my_float_2
product_of_floats = my_float_1 * my_float_2
division_of_floats = my_float_1 / my_float_2
print(sum_of_floats)
print(subtraction_of_floats)
print(product_of_floats)
print(division_of_floats)
# Out:
# 4.35
# 1.9300000000000002
# 3.7994
# 2.59504132231405

# %%
my_int_1= 56
my_int_2 = 12

my_float_1 = 5.4
my_float_2 = 12.0

mod_int = my_int_1 % my_int_2
mod_float = my_float_2 % my_float_1
print(mod_int)  
print(mod_float)
# Out:
# 8
# 1.1999999999999993

# %%
my_int_1= 56
my_int_2= 12

my_float_1 = 5.4
my_float_2 = 12.0

float_division_of_ints = my_int_1 // my_int_2
float_division_of_floats = my_float_2 // my_float_1
print(float_division_of_ints)
print(float_division_of_floats)
# Out:
# 4
# 2.0

# %%
my_int_1= 56
my_int_2= 12

my_float_1 = 5.4
my_float_2 = 12.0
exp_int = my_int_1 ** my_int_2
exp_float = my_float_1 ** my_float_2
print(exp_int)
print(exp_float)
# Out:
# 951166013805414055936
# 614787626.1765089

# %%
my_int_1= 56
my_float_1 = float(my_int_1)
print(my_float_1)
print(type(my_float_1))
# Out:
# 56.0
# <class 'float'>

# %%
my_float_1 = 3.14
my_int_1 = int(my_float_1)
print(my_int_1) 
print(type(my_int_1))
# Out:
# 3
# <class 'int'>

# %%
my_string_int_1 = "56"
my_string_float_1 = "3.14"
my_int_1 = int(my_string_int_1)
my_float_1 = float(my_string_float_1)   
print(my_int_1, type(my_int_1))
print(my_float_1, type(my_float_1))
# Out:
# 56 <class 'int'>
# 3.14 <class 'float'>

# %%
my_float_1 = 3.14
rounded_float_1 = round(my_float_1)
print(rounded_float_1)
# Out:
# 3

# %%
my_int_1= -56
abs_int_1 = abs(my_int_1)
print(abs_int_1)
# Out:
# 56

# %%
result_1 = pow(2, 3)
print(result_1)
result_2 = pow(2, 3, 5)
print(result_2)
# Out:
# 8
# 3
