# %%
my_var= 10
my_var += 5
print(my_var)
# Out:
# 15

# %%
count= 12
count -= 2
print(count)
# Out:
# 10

# %%
product= 8
product *= 2
print(product)
# Out:
# 16

# %%
price= 100
price /= 4
print(price)
# Out:
# 25.0

# %%
floor_div= 7
floor_div //= 2
print(floor_div)
# Out:
# 3

# %%
mod=35
mod %= 2
print(mod)
# Out:
# 1

# %%
power= 2
power **= 3
print(power)
# Out:
# 8

# %%
greeting= "Hello"
greeting += " World"    
print(greeting)
# Out:
# Hello World

# %%
greeting= "Hello"
greeting *= 3
print(greeting)
# Out:
# HelloHelloHello

# %%
my_var= 10
print(+my_var)
print(++my_var)
print(+++my_var)
my_var += 5
print(my_var)
# Out:
# 10
# 10
# 10
# 15
