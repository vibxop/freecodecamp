# %%
numbers = (1, 2, 3, 4, 5)
numbers[-2]

# %%
developer = 'Jessica'
tuple(developer) # ('J', 'e', 's', 's', 'i', 'c', 'a')

# %%
programming_languages = ('Python', 'JavaScript', 'C++')
programming_languages.index('JavaScript') # 1
